# %% [markdown]
# <a href="https://colab.research.google.com/github/KSeungBin/ros_deeplearning/blob/master/02_tank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ubuntu linux 운영시스템
# google drive
# local computer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
img = cv2.imread('/content/drive/MyDrive/image_detection/nuri.jpeg',1)
print(img.ndim)
print(img.shape)
# Out:
# 3
# (168, 300, 3)

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !nvidia-smi
# Out:
# Tue Jan 18 01:42:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import cv2
from matplotlib import pyplot as plt  #이미지 처리
img = cv2.imread('/content/drive/MyDrive/image_detection/tank.png',1)
#img = cv2.imread('/content/drive/MyDrive/image_detection/nuri.jpeg',1)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=305x165 at 0x7FDD3D6515D0>

# %%
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/image_detection/nuri.jpeg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
(R,G,B) = cv2.split(img)
cv2.imwrite("/content/drive/MyDrive/image_detection/nuri_R.png",R)
# Out:
# True

# %%
img = cv2.imread('/content/drive/MyDrive/image_detection/nuri_R.png', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img.shape
# Out:
# (168, 300, 3)
